# %% [markdown]
# <h1>Regions Cut By Slashes</h1><p>In a N x N&nbsp;<code>grid</code> composed of 1 x 1 squares, each 1 x 1 square consists of a <code>/</code>, <code>\</code>, or blank space.&nbsp; These characters divide the square into contiguous regions.</p><div></div><div></div><p>(Note that backslash characters are escaped, so a <code>\</code>&nbsp;is represented as <code>&quot;\\&quot;</code>.)</p><div></div><div></div><p>Return the number of regions.</p><div></div><div></div><p>&nbsp;</p><div></div><div></div><div><div></div><div><div></div><div><div></div><div><div></div><div><div></div><ol><div></div></ol><div></div></div><div></div></div><div></div></div><div></div></div><div></div></div><div></div><div></div><div><div></div><p><strong>Example 1:</strong></p><div></div><div></div><pre><div></div><strong>Input:<div></div></strong><span id="example-input-1-1">[<div></div>&nbsp; &quot; /&quot;,<div></div>&nbsp; &quot;/ &quot;<div></div>]</span><div></div><strong>Output: </strong><span id="example-output-1">2</span><div></div><strong>Explanation: </strong>The 2x2 grid is as follows:<div></div><img alt="" src="https://assets.leetcode.com/uploads/2018/12/15/1.png" style="width: 82px; height: 82px;" /><div></div></pre><div></div><div></div><div><div></div><p><strong>Example 2:</strong></p><div></div><div></div><pre><div></div><strong>Input:<div></div></strong><span id="example-input-2-1">[<div></div>&nbsp; &quot; /&quot;,<div></div>&nbsp; &quot;  &quot;<div></div>]</span><div></div><strong>Output: </strong><span id="example-output-2">1</span><div></div><strong>Explanation: </strong>The 2x2 grid is as follows:<div></div><img alt="" src="https://assets.leetcode.com/uploads/2018/12/15/2.png" style="width: 82px; height: 82px;" /><div></div></pre><div></div><div></div><div><div></div><p><strong>Example 3:</strong></p><div></div><div></div><pre><div></div><strong>Input:<div></div></strong><span id="example-input-3-1">[<div></div>&nbsp; &quot;\\/&quot;,<div></div>&nbsp; &quot;/\\&quot;<div></div>]</span><div></div><strong>Output: </strong><span id="example-output-3">4</span><div></div><strong>Explanation: </strong>(Recall that because \ characters are escaped, &quot;\\/&quot; refers to \/, and &quot;/\\&quot; refers to /\.)<div></div>The 2x2 grid is as follows:<div></div><img alt="" src="https://assets.leetcode.com/uploads/2018/12/15/3.png" style="width: 82px; height: 82px;" /><div></div></pre><div></div><div></div><div><div></div><p><strong>Example 4:</strong></p><div></div><div></div><pre><div></div><strong>Input:<div></div></strong><span id="example-input-4-1">[<div></div>&nbsp; &quot;/\\&quot;,<div></div>&nbsp; &quot;\\/&quot;<div></div>]</span><div></div><strong>Output: </strong><span id="example-output-4">5</span><div></div><strong>Explanation: </strong>(Recall that because \ characters are escaped, &quot;/\\&quot; refers to /\, and &quot;\\/&quot; refers to \/.)<div></div>The 2x2 grid is as follows:<div></div><img alt="" src="https://assets.leetcode.com/uploads/2018/12/15/4.png" style="width: 82px; height: 82px;" /><div></div></pre><div></div><div></div><div><div></div><p><strong>Example 5:</strong></p><div></div><div></div><pre><div></div><strong>Input:<div></div></strong><span id="example-input-5-1">[<div></div>&nbsp; &quot;//&quot;,<div></div>&nbsp; &quot;/ &quot;<div></div>]</span><div></div><strong>Output: </strong><span id="example-output-5">3</span><div></div><strong>Explanation: </strong>The 2x2 grid is as follows:<div></div><img alt="" src="https://assets.leetcode.com/uploads/2018/12/15/5.png" style="width: 82px; height: 82px;" /><div></div></pre><div></div><div></div><p>&nbsp;</p><div></div><div></div><p><strong>Note:</strong></p><div></div><div></div><ol><div></div>	<li><code>1 &lt;= grid.length == grid[0].length &lt;= 30</code></li><div></div>	<li><code>grid[i][j]</code> is either <code>&#39;/&#39;</code>, <code>&#39;\&#39;</code>, or <code>&#39; &#39;</code>.</li><div></div></ol><div></div></div><div></div></div><div></div></div><div></div></div><div></div></div><div></div>

# %%
# %%writefile regions_cut_by_slashes.py
class Solution:
    def regionsBySlashes(self, grid):
        """
        :type grid: List[str]
        :rtype: int
        """

# %%
# submit
# %run ../../cli.py push --method=submit --path=regions_cut_by_slashes.py --clean=True
