# %% [markdown]
# <h1>Surface Area of 3D Shapes</h1><p>On a&nbsp;<code>N&nbsp;*&nbsp;N</code>&nbsp;grid, we place some&nbsp;<code>1 * 1 * 1&nbsp;</code>cubes.</p><div></div><div></div><p>Each value&nbsp;<code>v = grid[i][j]</code>&nbsp;represents a tower of&nbsp;<code>v</code>&nbsp;cubes placed on top of grid cell&nbsp;<code>(i, j)</code>.</p><div></div><div></div><p>Return the total surface area of the resulting shapes.</p><div></div><div></div><p>&nbsp;</p><div></div><div></div><div><div></div><div><div></div><div><div></div><ul><div></div></ul><div></div></div><div></div></div><div></div></div><div></div><div></div><div><div></div><p><strong>Example 1:</strong></p><div></div><div></div><pre><div></div><strong>Input: </strong><span id="example-input-1-1">[[2]]</span><div></div><strong>Output: </strong><span id="example-output-1">10</span><div></div></pre><div></div><div></div><div><div></div><p><strong>Example 2:</strong></p><div></div><div></div><pre><div></div><strong>Input: </strong><span id="example-input-2-1">[[1,2],[3,4]]</span><div></div><strong>Output: </strong><span id="example-output-2">34</span><div></div></pre><div></div><div></div><div><div></div><p><strong>Example 3:</strong></p><div></div><div></div><pre><div></div><strong>Input: </strong><span id="example-input-3-1">[[1,0],[0,2]]</span><div></div><strong>Output: </strong><span id="example-output-3">16</span><div></div></pre><div></div><div></div><div><div></div><p><strong>Example 4:</strong></p><div></div><div></div><pre><div></div><strong>Input: </strong><span id="example-input-4-1">[[1,1,1],[1,0,1],[1,1,1]]</span><div></div><strong>Output: </strong><span id="example-output-4">32</span><div></div></pre><div></div><div></div><div><div></div><p><strong>Example 5:</strong></p><div></div><div></div><pre><div></div><strong>Input: </strong><span id="example-input-5-1">[[2,2,2],[2,1,2],[2,2,2]]</span><div></div><strong>Output: </strong><span id="example-output-5">46</span><div></div></pre><div></div><div></div><p>&nbsp;</p><div></div><div></div><p><strong>Note:</strong></p><div></div><div></div><ul><div></div>	<li><code>1 &lt;= N &lt;= 50</code></li><div></div>	<li><code>0 &lt;= grid[i][j] &lt;= 50</code></li><div></div></ul><div></div></div><div></div></div><div></div></div><div></div></div><div></div></div><div></div><div></div>

# %%
# %%writefile surface_area_of_3d_shapes.py
class Solution:
    def surfaceArea(self, grid):
        """
        :type grid: List[List[int]]
        :rtype: int
        """

# %%
# submit
# %run ../../cli.py push --method=submit --path=surface_area_of_3d_shapes.py --clean=True
